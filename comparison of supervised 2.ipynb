# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

import numpy as np

# %%
x=[]
np.random.seed(1)
for i in range(5):
    x.append(np.random.rand(10000))
y_class=[1,0]
y = [np.random.choice(y_class) for i in range(10000)]
x_keys = ['x1','x2','x3','x4','x5']
x_dict = {key:value for key,value in zip(x_keys,x)}
X = pd.DataFrame(x_dict)
X.head()
# Out:
#          x1        x2        x3        x4        x5
# 0  0.417022  0.765497  0.805802  0.359340  0.878726
# 1  0.720324  0.308173  0.541587  0.945030  0.041940
# 2  0.000114  0.735378  0.878887  0.835340  0.681875
# 3  0.302333  0.812198  0.947535  0.121024  0.502068
# 4  0.146756  0.236694  0.832790  0.375893  0.148241

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.3)

# %%
#model = LogisticRegression()
#model = svm.LinearSVC()
#model = GaussianNB()
#model = KNeighborsClassifier()
model = RandomForestClassifier()

model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print(prediction)
# Out:
# [0 0 0 ... 1 0 0]

# %%
from sklearn.metrics import accuracy_score,classification_report,f1_score,precision_score,recall_score,roc_auc_score,log_loss

# %%
accuracy = accuracy_score(y_test,y_pred)
classification = classification_report(y_test,y_pred)
f1 = f1_score(y_test,y_pred)
precision = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
logloss = log_loss(y_test,y_pred)
roc_auc = roc_auc_score(y_test,y_pred)

print("accuracy=",accuracy)
print("\nclassification =")
print(classification)
print("f1-score=",f1)
print("precision=",precision)
print("recall=",recall)
print("log loss =",logloss)
print("roc_auc score=",roc_auc)
# Out:
# accuracy= 0.5033333333333333
#
# classification =
#               precision    recall  f1-score   support
#
#            0       0.50      0.54      0.52      1498
#            1       0.50      0.47      0.49      1502
#
#     accuracy                           0.50      3000
#    macro avg       0.50      0.50      0.50      3000
# weighted avg       0.50      0.50      0.50      3000
#
# f1-score= 0.48726772195457674
# precision= 0.5042735042735043
# recall= 0.47137150466045274
# log loss = 17.154444449409446
# roc_auc score= 0.5033760060017884

# %%
#model_df = pd.DataFrame([['Logistic Regression',accuracy,f1,precision,recall,logloss,roc_auc]],
                        #columns=['Model','Accuracy','f1-score','Precision','Recall','Log loss','ROC-AUC'])
#model_df

# %%
#model_df.to_csv("Model_comparison_classifiers.csv")

# %%
#model_df.loc[-1]=['Support Vector Machine',accuracy,f1,precision,recall,logloss,roc_auc]
#model_df.loc[-1]=['Gaussian Naive Bayes',accuracy,f1,precision,recall,logloss,roc_auc]
#model_df.loc[-1]=['K Nearest Neighbor',accuracy,f1,precision,recall,logloss,roc_auc]
model_df.loc[-1]=['Random Forest Classifier',accuracy,f1,precision,recall,logloss,roc_auc]
model_df.index=model_df.index+1

# %%
model_df
# Out:
#                       Model  Accuracy  f1-score  Precision    Recall  \
# 4       Logistic Regression  0.495000  0.402838   0.493720  0.340213
# 3    Support Vector Machine  0.494000  0.403302   0.492322  0.341545
# 2      Gaussian Naive Bayes  0.500333  0.416050   0.501408  0.355526
# 1        K Nearest Neighbor  0.502667  0.497305   0.503411  0.491345
# 0  Random Forest Classifier  0.503333  0.487268   0.504274  0.471372
#
#     Log loss   ROC-AUC
# 4  17.442222  0.495207
# 3  17.476762  0.494204
# 2  17.258017  0.500527
# 1  17.177479  0.502682
# 0  17.154444  0.503376

# %%
model_df=model_df.sort_index()
model_df
# Out:
#                       Model  Accuracy  f1-score  Precision    Recall  \
# 0  Random Forest Classifier  0.503333  0.487268   0.504274  0.471372
# 1        K Nearest Neighbor  0.502667  0.497305   0.503411  0.491345
# 2      Gaussian Naive Bayes  0.500333  0.416050   0.501408  0.355526
# 3    Support Vector Machine  0.494000  0.403302   0.492322  0.341545
# 4       Logistic Regression  0.495000  0.402838   0.493720  0.340213
#
#     Log loss   ROC-AUC
# 0  17.154444  0.503376
# 1  17.177479  0.502682
# 2  17.258017  0.500527
# 3  17.476762  0.494204
# 4  17.442222  0.495207

# %%
model_df.to_csv("Model_comparison_classifiers.csv")
